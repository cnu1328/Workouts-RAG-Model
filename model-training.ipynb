# %%
import pandas as pd
import os
import pickle
from langchain_community.vectorstores import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.documents import Document
from dotenv import load_dotenv

load_dotenv()
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# === Configuration ===
EXCEL_PATH = "dataset/Workouts.xlsx"
CHROMA_DB_PATH = os.path.expanduser("~/chroma_workout_db")
METADATA_FILE = "workout_chroma_metadata.pkl"

# === Embedding Model ===
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# === Load Excel ===
def load_excel_data(excel_path):
    df = pd.read_excel(excel_path)
    return df

# === Prepare Documents for Chroma ===
def prepare_documents(df):
    documents = []
    for idx, row in df.iterrows():
        # Convert the input columns to a natural language string
        input_str = row['input']
        output_str = row["output"]
        print(f"Processing row {idx} \n Input: {input_str} \n Output: {output_str}\n\n")
        metadata = {
            "row_index": idx,
            "input": input_str,
            "output": output_str
        }
        documents.append(Document(page_content=input_str, metadata=metadata))
    return documents

# === Create and Save Vector Database ===
def create_and_save_vector_db(documents):
    vector_store = Chroma.from_documents(documents, embeddings, persist_directory=CHROMA_DB_PATH)
    # vector_store.persist()
    with open(METADATA_FILE, "wb") as f:
        pickle.dump(documents, f)
    print("Vector DB and metadata saved.")

# === Entry point ===
if __name__ == "__main__":
    df = load_excel_data(EXCEL_PATH)
    documents = prepare_documents(df)
    create_and_save_vector_db(documents)
# Out:
# Processing row 0
#  Input: Fitness Level: Beginner; Workout Frequency: 2-3 days per week; Available Equipment: None; Primary Goal: Lose Weight; Workout Type: Strength Training; Specific Equipment Details: pull-up bar; Session Duration: 15-30 minutes; Focus Areas: arms, legs, chest; Health Limitation: None
#  Output:
# Overview & Strategy
# As a beginner aiming to lose weight with no equipment except a pull-up bar, and training 2–3 days per week for 15–30 minutes per session, the goal is to focus on full-body strength training circuits using bodyweight exercises. These workouts are designed to be simple, effective, and progressively build strength while maximizing calorie burn.
#
# We’ll split the week into two structured strength-focused days and an optional third day for light conditioning or mobility.
#
# Weekly Workout Plan
# Day 1 – Full Body Strength Focus (Arms + Legs + Chest)
# Workout Type: Circuit Training
#
# Duration: ~25 minutes
#
# Warm-up (5 min)
#
# Arm circles x 20
#
# Bodyweight squats x 15
#
# High knees x 30 sec
#
# Inchworms x 5
#
# Jumping jacks x 30 sec
#
# Main Workout – 3 Rounds
#
# Push-Ups – 10–12 reps (chest, arms)
#
# Bodyweight Squats – 15 reps (legs)
#
# Incline Push-Ups (on a table) – 8–10 reps
#
# Wall Sit – 30 seconds (legs & endurance)
#
# Negative Pull-Ups (use pull-up bar) – 3–5 reps, slow descent
#
# Plank – 30 seconds (core)
#
# Rest: 45 seconds between exercises; 60–90 seconds between rounds.
#
# Cooldown (3–5 min)
#
# Chest stretch on wall
#
# Seated hamstring stretch
#
# Shoulder rolls
#
# Deep breathing (box breathing x 3 rounds)
#
# Day 2 – Lower Body + Core Focus
# Workout Type: Superset-Based Strength Training
#
# Duration: ~30 minutes
#
# Warm-up (5 min)
#
# Arm swings x 20
#
# Walking lunges x 10 per leg
#
# Jumping jacks x 30 sec
#
# Air squats x 15
#
# Torso twists x 10
#
# Main Workout – Supersets (3 rounds each)
# Superset A
#
# Glute Bridges – 15 reps
#
# Wall Sits – 45 sec
#
# Superset B
#
# Step-Ups (use stairs or a chair) – 10 reps per leg
#
# Plank with Shoulder Tap – 30 seconds
#
# Superset C
#
# Squat Pulses – 15 reps
#
# Leg Raises – 12 reps
#
# Optional Finisher
#
# Pull-up Bar Dead Hangs – 30 seconds x 2 rounds
#
# Mountain Climbers – 30 sec x 2 rounds
#
# Cooldown (3–5 min)
#
# Forward fold (hamstring stretch)
#
# Downward dog
#
# Wrist stretch
#
# Deep belly breathing
#
# Optional Day 3 – Conditioning / Light Cardio + Mobility
# Workout Type: Active Recovery / Fat Burn
#
# Duration: 20–25 minutes
#
# Warm-up (as above)
#
# Light Circuit – 2 rounds
#
# Jog in place – 2 minutes
#
# Shadow boxing – 1 minute
#
# Jumping jacks – 1 minute
#
# Marching step-ups – 1 min
#
# Side lunges – 10 per side
#
# Standing oblique crunches – 15 reps per side
#
# Mobility Flow (5–8 min)
#
# Cat-Cow Stretch
#
# Hip Circles
#
# Standing quad stretch
#
# Wrist & shoulder mobility drills
#
# Controlled breathing
#
# Weekly Progression Strategy
# Week 1–2: Focus on mastering form.
#
# Week 3: Add 1–2 extra reps per exercise.
#
# Week 4: Reduce rest time slightly (5–10 seconds).
#
# Week 5: Add an extra round or include time-based circuits (e.g., 30 sec per move).
#
# General Recommendations
# Stay hydrated before and after workouts.
#
# Perform movements slowly and with control—no rushing.
#
# Track your reps and progress weekly.
#
# Listen to your body—if sore, take a day off.
#
# On non-training days, go for a 15–20 min walk if possible.
#
#
# Processing row 1
#  Input: Fitness Level: Beginner; Workout Frequency: 3-4 days per week; Available Equipment: Home Gym Setup; Primary Goal: Build Muscle; Workout Type: High Intensity Interval Training; Specific Equipment Details: pull-up bar, dumbbells 5-30lbs, kettlebells, resistance bands; Session Duration: 30-45 minutes; Focus Areas: arms, core, legs, chest; Health Limitation: None
#  Output: 💪 Weekly Workout Plan – Beginner | Goal: Build Muscle | HIIT | Home Gym Setup
# 👋 Introduction
# Welcome to your customized weekly workout plan designed to help you build muscle using High-Intensity Interval Training (HIIT) principles. Since you’re a beginner with access to a home gym and can commit to 3–4 sessions/week, we’ve tailored this plan to maximize muscle gain while also keeping it engaging, safe, and time-efficient. Sessions will stay within the 30–45 minute window and progressively challenge your arms, core, legs, and chest using the available equipment.
#
# 🔥 Weekly Schedule Overview
# Day	Focus Area	Format	Duration
# Day 1	Full Body (Upper Emphasis)	HIIT Strength Circuit	35 mins
# Day 2	Rest or Active Recovery	Stretch/Yoga	20 mins
# Day 3	Core + Lower Body	Superset HIIT	40 mins
# Day 4	Upper Body Focus (Push & Pull)	Pyramid Sets + HIIT	30–45 mins
# Day 5	Optional Bonus: Full Body Express	Tabata-Style HIIT	30 mins
# Days 6–7	Rest or Light Activity	Walk, Cycle	-
#
# 🧠 Key Concepts
# HIIT structure: Short bursts of intense work (40s) followed by short rest (20s).
#
# Progressive overload: Increase dumbbell/kettlebell weight slightly every 2–3 weeks.
#
# Minimal rest: 20–30 seconds between exercises; 60 seconds between rounds.
#
# 🔄 Daily Breakdown
# ✅ Day 1: Full Body – Upper Emphasis (HIIT Strength Circuit)
# Warm-up (5 mins): Arm swings, air squats, jumping jacks
# Circuit (3 rounds):
#
# Push-Ups → 40s
#
# Kettlebell Swings → 40s
#
# Dumbbell Bent-over Rows → 40s
#
# Resistance Band Chest Press → 40s
#
# Plank Hold → 40s
# Cooldown: Stretch chest, shoulders, arms (5 mins)
#
# ✅ Day 3: Core & Legs (Superset HIIT)
# Warm-up (5 mins): Leg swings, toe touches, hip openers
# Superset A (3 rounds):
#
# Goblet Squats (dumbbell) → 12 reps
#
# Russian Twists (bodyweight/dumbbell) → 30 sec
#
# Superset B (3 rounds):
#
# Step-ups (with dumbbells) → 10 reps/leg
#
# Leg Raises → 15 reps
#
# Finisher: 1-minute wall sit + 1-minute plank hold
# Cooldown: Hamstring & glute stretch
#
# ✅ Day 4: Upper Body Focus – Push & Pull
# Warm-up (5 mins): Shoulder rolls, band pull-aparts
# Pyramid Set (4 rounds):
#
# Pull-Ups (assisted if needed): 3 → 5 → 7 → 5
#
# Dumbbell Shoulder Press: 10–12 reps
#
# Dumbbell Bicep Curls: 12 reps
#
# Resistance Band Rows: 15 reps
#
# Finisher: 3 rounds of 30s Mountain Climbers + 10 push-ups
# Cooldown: Arm and back stretches
#
# ✅ Day 5 (Optional): Full Body Express (Tabata HIIT)
# 8 exercises, 20s on / 10s off x 4 rounds
#
# Jump Squats
#
# Dumbbell Snatches
#
# Kettlebell Deadlifts
#
# Push-Ups
#
# Bicycle Crunches
#
# Dumbbell Lateral Raises
#
# Pull-Up Hold
#
# Burpees
#
# Cooldown: Light walk and full-body stretch
#
# 💡 Weekly Progression Strategy
# Week 2–3: Increase reps or add 5–10% more resistance
#
# Week 4: Include 1 more round to each circuit
#
# Focus on form over speed
#
# Log your workouts to track improvements
#
# 🧘 Warm-Up & Cooldown Guidelines
# Warm-Up (5 mins each session):
#
# Jumping jacks, arm circles, dynamic stretches
# Cooldown (5 mins):
#
# Static stretching for all trained muscle groups
#
# Focus on breathing and recovery
#
# 🚫 Safety Notes
# Avoid rushing through reps—use full range of motion
#
# Stop immediately if you feel pain (not to be confused with normal burn)
#
# Stay hydrated and take an extra rest day if needed
#
#
# Processing row 2
#  Input: Fitness Level: Intermediate; Workout Frequency: 3-4 days per week; Available Equipment: Home Gym Setup; Primary Goal: Build Muscle; Workout Type: High Intensity Interval Training; Specific Equipment Details: pull-up bar, dumbbells 5-30lbs, kettlebells, resistance bands; Session Duration: 30-45 minutes; Focus Areas: arms, core, legs, chest; Health Limitation: None
#  Output: 💪 Weekly Workout Plan – Intermediate | Goal: Build Muscle | HIIT | Home Gym Setup
# 👋 Introduction
# This intermediate-level weekly workout plan is designed to help you build lean muscle efficiently with High-Intensity Interval Training (HIIT). Using your home gym setup and focusing on your chosen areas — arms, core, legs, and chest — you’ll perform challenging and engaging routines spread across 3–4 days per week. Workouts will last between 30–45 minutes and utilize all available equipment strategically.
#
# 🔥 Weekly Schedule Overview
# Day	Focus Area	Format	Duration
# Day 1	Upper Body (Chest + Arms)	HIIT Strength Split	40 mins
# Day 2	Core + Conditioning	Core Circuits + Tabata	30–35 mins
# Day 3	Lower Body (Legs + Glutes)	Superset HIIT	40–45 mins
# Day 4	Optional Full-Body Burn	Dumbbell/Kettlebell HIIT	30 mins
# Days 5–7	Active Recovery/Rest	Stretching or Walks	15–20 mins
# 🔄 Day-by-Day Workout Plan
# ✅ Day 1 – Chest + Arms HIIT Split
# Warm-up (5 mins): Arm circles, band pull-aparts, push-ups x10
# Circuit (3 rounds)
#
# Dumbbell Chest Press – 12 reps
# Push-Ups – 15 reps
# Dumbbell Bicep Curls – 12 reps
# Resistance Band Tricep Extensions – 12 reps
# Plank Shoulder Taps – 40 sec
# Rest: 30s between exercises, 60s between rounds
# Cooldown: Stretch chest, triceps, biceps (5 mins)
# ✅ Day 2 – Core + Conditioning
# Warm-up (5 mins): Leg raises, bodyweight squats
# Core Blast (3 rounds)
#
# Russian Twists with Dumbbell – 30s
# V-Ups – 15 reps
# Dumbbell Woodchoppers – 12 reps per side
# Hollow Body Hold – 30s
# Tabata Finisher (20s on/10s off × 4 sets)
# High Knees
# Burpees
# Cooldown: Ab stretches, deep breathing
# ✅ Day 3 – Lower Body + Glutes
# Warm-up (5 mins): Glute bridges, air squats, jump rope
# Superset A (3 rounds):
#
# Goblet Squats – 12 reps
# Resistance Band Lateral Walks – 12 reps/side
# Superset B (3 rounds):
# Kettlebell Deadlifts – 10 reps
# Step-Ups (with dumbbells) – 10 reps/leg
# Finisher: Wall Sit (1 min) + Calf Raises (20 reps)
# Cooldown: Hamstring & quad stretches
# ✅ Day 4 (Optional) – Full-Body Burn
# Warm-up (5 mins): Jumping jacks, light kettlebell swings
# Dumbbell/Kettlebell HIIT (3 rounds)
#
# Kettlebell Swings – 15 reps
# Dumbbell Thrusters – 12 reps
# Pull-Ups – 5–8 reps
# Dumbbell Renegade Rows – 10 reps/side
# Jump Squats – 12 reps
# Cooldown: Full-body stretch
# 🧘 Warm-up & Cooldown Guidelines
# Warm-Up (every day): 5 mins light cardio + mobility
# Cooldown: Stretch trained areas + deep breathing (5 mins)
# 📈 Progression Strategy
# Every 2 weeks: Increase dumbbell/kettlebell weight by 5–10%
# Add 1 extra round to each workout after 3 weeks
# Increase time in core planks/wall sits progressively
# 🛡️ Safety Notes
# Focus on controlled movements, avoid jerky reps
# Stay hydrated and take rest days if sore
# Maintain proper form, especially during kettlebell swings or deadlifts
# Use assisted pull-ups if needed
#
#
# Processing row 3
#  Input: Fitness Level: Advanced; Workout Frequency: 5-6 days per week; Available Equipment: Full Gym Access; Primary Goal: Increase Strength; Workout Type: High Intensity Interval Training; Specific Equipment Details: pull-up bar, dumbbells 5-30lbs, kettlebells, resistance bands; Session Duration: 30-45 minutes; Focus Areas: arms, core, legs, chest; Health Limitation: Right Hand Wrist Pain
#  Output: 🏋️‍♂️ Weekly Workout Plan – Advanced | Goal: Increase Strength | HIIT | Full Gym Access
# 🔎 Strategy Overview
# This advanced plan is structured to increase total body strength using High-Intensity Interval Training (HIIT) methods while leveraging full gym access. It strategically emphasizes the arms, core, legs, and chest across 5–6 weekly sessions, ensuring high effort and measurable progression.
#
# Due to right-hand wrist pain, all workouts are designed to minimize wrist loading by avoiding or modifying exercises like barbell presses, push-ups, or planks. Emphasis is placed on safe grip alternatives (e.g., straps, neutral grips) and lower-wrist-strain movements.
#
# 📅 Weekly Schedule
# Day	Focus	Format	Duration
# Day 1	Lower Body Strength	Compound Supersets	40 mins
# Day 2	Core + Mobility	Core Circuit + HIIT	30–35 mins
# Day 3	Upper Body (Back + Chest)	Power HIIT	45 mins
# Day 4	Active Recovery	Mobility + Resistance Band	30 mins
# Day 5	Legs + Glutes	Unilateral Strength	40–45 mins
# Day 6	Full-Body Conditioning	Dumbbell + Kettlebell HIIT	40 mins
# Day 7	Rest	—	—
# 🏋️ Workout Details
# 🔥 Day 1 – Lower Body Strength Focus
# Warm-up: 5 mins rower + hip openers
# Main Set (3 rounds):
#
# Barbell Back Squats – 6–8 reps
# Romanian Deadlifts (Straps if needed) – 8 reps
# Leg Press – 10 reps
# Dumbbell Walking Lunges – 20 steps
# Finisher: Jump squats – 3x15
# Cooldown: Foam rolling + hamstring/hip flexor stretch
# 💥 Day 2 – Core + Mobility HIIT
# Warm-up: 5 mins elliptical
# Core Circuit (3 rounds):
#
# Decline Sit-Ups – 15 reps
# Hanging Knee Raises (w/ straps) – 12 reps
# Cable Woodchoppers – 12 reps/side
# Bicycle Crunches – 30s
# Finisher: HIIT Bike Sprints – 20s ON / 40s OFF × 6 rounds
# Cooldown: Deep breathing + cobra + child's pose
# 💪 Day 3 – Chest + Back (Wrist-Friendly)
# Warm-up: Resistance band pull-aparts + lat activation
# Power Circuit (3 rounds):
#
# Machine Chest Press – 8–10 reps
# Seated Cable Row – 10 reps
# Lat Pulldown (Wide Grip) – 10 reps
# Incline Chest Fly Machine – 12 reps
# Resistance Band Face Pulls – 15 reps
# Avoid: Barbell bench press, push-ups
# Cooldown: Shoulder and lat stretches
# 🧘 Day 4 – Active Recovery
# Routine:
#
# Resistance Band External Rotations – 3x15
# Glute Bridges – 3x20
# Band Pull-Aparts – 3x20
# Yoga flow: cat-cow, pigeon pose, spinal twist
# Goal: Mobility, recovery, blood flow
# 🦵 Day 5 – Glutes + Legs Strength
# Warm-up: Kettlebell swings + step-ups
# Main (3 rounds):
#
# Bulgarian Split Squats – 10 reps/leg
# Sled Push or Heavy Step-ups – 20m or 12 reps
# Kettlebell Goblet Squats – 12 reps
# Single-Leg Deadlift (with straps if needed) – 10 reps/leg
# Cooldown: Hamstring band stretch + hip mobility work
# 🔄 Day 6 – Full-Body HIIT Burn
# Warm-up: 5 mins light rowing
# HIIT Rounds (3 sets of the following):
#
# Dumbbell Snatch (Alternate Arm) – 10 reps
# Kettlebell Swings – 20 reps
# Pull-Ups (Assisted if needed) – 8–10 reps
# Air Bike Sprint – 20s
# Box Step-Overs – 10 reps/side
# Cooldown: Full-body stretch, foam roll
# ⚙️ Progression Tips
# Increase dumbbell/kettlebell weight every 1–2 weeks
# Add 1 round per circuit every 2 weeks
# Use rest-pause or slow negatives to increase intensity safely
# 🚨 Health & Safety (Wrist)
# Avoid: Push-ups, front-loaded barbell pressing, heavy dips
# Modify: Use machines or neutral grip dumbbells/kettlebells
# Use straps to reduce wrist strain during pulling exercises
# Monitor wrist and rest immediately if pain increases
# 🧘 Warm-Up & Cooldown
# Warm-up: Dynamic stretches, joint circles, cardio (5 min)
# Cooldown: Foam rolling, deep static stretches (5–8 min)
#
#
# Processing row 4
#  Input: Fitness Level: Intermediate; Workout Frequency: 5-6 days per week; Available Equipment: Full Gym Access; Primary Goal: Increase Strength; Workout Type: Functional Fitness; Specific Equipment Details: pull-up bar, dumbbells 5–30lbs, kettlebells, resistance bands; Session Duration: 30–45 minutes; Focus Areas: arms, core, legs, chest; Health Limitation: None
#  Output: 🏋️‍♀️ Weekly Functional Fitness Strength Plan – Intermediate Level
# 📘 Overview:
# This 5–6 day plan is designed for an intermediate-level trainee aiming to increase total-body strength using functional fitness principles. Functional strength training improves not just raw power but also movement quality, coordination, and joint stability using compound and real-world movement patterns.
#
# You’ll be training with a full gym setup, incorporating tools like dumbbells, kettlebells, resistance bands, and a pull-up bar. The workouts rotate between upper/lower splits, core-focused functional circuits, and dynamic total-body sessions. Each day includes proper warm-up, progressive strength loading, and a brief cooldown.
#
# 📅 Weekly Schedule
# Day	Focus Area(s)	Workout Type	Duration
# Day 1	Lower Body + Core	Functional Strength	40–45 mins
# Day 2	Upper Body Push (Chest, Arms)	Functional Circuit	40 mins
# Day 3	Core + Mobility	Stability + HIIT	30–35 mins
# Day 4	Lower Body Power	Explosive Training	40–45 mins
# Day 5	Upper Body Pull + Core	Strength + Pulling	40 mins
# Day 6	Total Body Movement	Functional Metcon	45 mins
# Day 7	Rest or Light Mobility	—	—
# 🔥 Day 1 – Lower Body + Core
# Warm-up
#
# 5 mins treadmill walk + leg swings + glute activation
# Main Circuit (3 Rounds)
#
# Kettlebell Goblet Squat – 10 reps
# Dumbbell Step-ups (holding dumbbells) – 10 reps/leg
# Glute Ham Raise (or machine alternative) – 8–10 reps
# Hanging Knee Raises – 15 reps
# Plank w/ Band Row (resistance band) – 10/side
# Rest: 60–90s between rounds
# Cooldown: Hamstring + quad foam rolling
#
# 💪 Day 2 – Upper Body Push (Chest, Arms)
# Warm-up
#
# Resistance band shoulder activation + push-ups x10
# Main Circuit (3 Rounds)
#
# Incline Dumbbell Press – 10 reps
# Dumbbell Arnold Press – 12 reps
# Resistance Band Chest Fly – 15 reps
# Overhead Dumbbell Triceps Extensions – 12 reps
# Wall Ball Slams or Med Ball Throws – 10 explosive reps
# Rest: 60s between sets
# Cooldown: Chest and shoulder stretches
#
# 💥 Day 3 – Core + Mobility
# Warm-up
#
# Dynamic trunk rotations + jump rope (2 mins)
# Functional Core Set (2–3 Rounds)
#
# Cable Woodchoppers – 12 reps/side
# Reverse Crunches – 15 reps
# Resistance Band Deadbugs – 10/side
# Bear Crawl Hold – 30s hold
# Russian Twists (light kettlebell) – 20 reps
# Cooldown: Deep hip flexor + oblique stretch
#
# 🦵 Day 4 – Lower Body Power
# Warm-up
#
# Skater jumps + hip mobility drills
# Explosive Strength Circuit (4 Rounds)
#
# Trap Bar Deadlift – 6 reps (heavy, focus on form)
# Kettlebell Swings – 20 reps
# Box Jumps – 10 reps
# Walking Lunges (Dumbbell) – 12/leg
# Band-Resisted Lateral Walks – 15 steps/side
# Rest: 90s between rounds
# Cooldown: Quad/hamstring/ankle mobility
#
# 💪 Day 5 – Upper Body Pull + Core
# Warm-up
#
# Band pull-aparts + light rows
# Main Set (3 Rounds)
#
# Pull-ups (assisted if needed) – Max reps
# Seated Cable Row – 12 reps
# Resistance Band Bicep Curls – 15 reps
# Dumbbell Shrugs – 15 reps
# Weighted Plank Hold – 30–45 sec
# Cooldown: Neck and upper back mobility
#
# 🔄 Day 6 – Total Body Functional Metcon
# Warm-up
#
# Jump rope + mobility drills (3 mins)
# Metcon (Repeat 3–4 Times):
#
# Dumbbell Clean + Press – 10 reps
# Kettlebell Swings – 20 reps
# Burpees – 10 reps
# Pull-ups – 8 reps
# Dumbbell Thrusters – 10 reps
# Jump Rope – 1 min
# Rest: 1 min between rounds
# Cooldown: Full-body foam rolling + breathing drills
#
# 📈 Progression Tips
# Week 2+: Add 1 set or 5–10% load on key lifts
# Increase time-under-tension (slow eccentric) in functional lifts
# Improve control in core stability moves week over week
# 🧘 Warm-Up & Cooldown Template
# Warm-Up (5–7 mins)
#
# Light cardio (treadmill, jump rope, rower)
# Dynamic stretches (leg swings, shoulder circles)
# 1 activation drill (glutes, core, or scapular)
# Cooldown (5–8 mins)
#
# Targeted static stretches (hold 30–45s)
# Breathing-focused relaxation stretch (e.g., lying spinal twist)
#
#
# Processing row 5
#  Input: Fitness Level: Beginner; Workout Frequency: 2-3 days per week; Available Equipment: Full Gym Access; Primary Goal: General Fitness; Workout Type: Functional Fitness; Specific Equipment Details: pull-up bar, dumbbells 5–30 lbs, kettlebells, resistance bands; Session Duration: 15–30 minutes; Focus Areas: arms, core, legs, chest; Health Limitations: None
#  Output: Weekly Functional Fitness Plan for a Beginner (General Fitness)
# 🔍 Overview:
# Welcome! This 3-day weekly functional fitness plan is designed to help you build overall strength, improve mobility, and increase energy—all within 15–30 minutes per session. Since you're a beginner with full gym access and a focus on arms, legs, core, and chest, each workout is full-body, emphasizing movement patterns useful in daily life. You'll progress by improving form and increasing reps or resistance weekly.
#
# 📅 Weekly Schedule:
# Day 1: Full Body Strength + Core
#
# Day 2: Active Recovery or Rest
#
# Day 3: Lower Body + Core Focus
#
# Day 4: Rest
#
# Day 5: Upper Body + Core Focus
#
# Day 6–7: Rest / Optional Light Activity (e.g., Walk, Yoga)
#
# 🔥 DAY 1 – Full Body Strength + Core
# Workout Type: Circuit
#
# Duration: ~25 min
#
# Focus Areas: Full body + Core
#
# 🧊 Warm-Up (5 min):
# Arm circles × 15 reps
#
# Bodyweight squats × 10
#
# High knees × 30 sec
#
# Shoulder rolls × 10
#
# Cat-Cow stretch × 5 rounds
#
# 💪 Workout (Perform 3 rounds with 60s rest between rounds):
# Exercise	Equipment	Reps
# Goblet Squat	Kettlebell	12
# Dumbbell Chest Press (on bench/floor)	Dumbbells	10
# Bent-Over Dumbbell Row	Dumbbells	10 each arm
# Dead Bug	Bodyweight	12 (each side)
# Resistance Band Pull-Apart	Resistance Band	15
#
# 🧘 Cooldown (3–5 min):
# Hamstring stretch
#
# Child’s pose
#
# Deep belly breathing × 5 breaths
#
# 🦵 DAY 3 – Lower Body + Core
# Workout Type: Strength Circuit
#
# Duration: ~25 min
#
# Focus Areas: Legs, Glutes, Core
#
# 🧊 Warm-Up (5 min):
# Jumping jacks × 30 sec
#
# Glute bridges × 10
#
# Hip circles × 10 each direction
#
# 💪 Workout (3 rounds):
# Exercise	Equipment	Reps
# Kettlebell Deadlift	Kettlebell	12
# Step-Ups (use gym bench/box)	Bodyweight or Dumbbells	10 each leg
# Dumbbell Walking Lunges	Dumbbells	10 each leg
# Plank Shoulder Taps	Bodyweight	12 each side
# Banded Side Steps	Resistance Band	15 each direction
#
# 🧘 Cooldown:
# Pigeon pose
#
# Forward fold
#
# Seated spinal twist
#
# 💪 DAY 5 – Upper Body + Core
# Workout Type: Functional Strength
#
# Duration: ~25 min
#
# Focus Areas: Arms, Chest, Shoulders, Core
#
# 🧊 Warm-Up (5 min):
# Arm swings × 10
#
# Wall angels × 10
#
# Wrist circles × 10 each side
#
# 💪 Workout (3 rounds):
# Exercise	Equipment	Reps
# Incline Push-Ups (or regular)	Bodyweight	10–12
# Dumbbell Shoulder Press	Dumbbells	10
# Kettlebell Upright Row	Kettlebell	12
# Russian Twists	Bodyweight	15 each side
# Hanging Knee Raises	Pull-Up Bar	10–12
#
# 🧘 Cooldown:
# Triceps stretch
#
# Chest opener stretch
#
# Gentle spinal twist
#
# 📈 Weekly Progression Strategy:
# Week 1–2: Focus on form and consistency.
#
# Week 3+: Gradually increase weight or reps (1–2 per set).
#
# Optional: Add a 4th light activity day (e.g., yoga or stretching).
#
# ✅ Safety Notes:
# Maintain controlled movements—don’t rush reps.
#
# Always engage your core during exercises.
#
# Hydrate before and after.
#
# Stop immediately if you feel pain (not to be confused with effort).
#
#
#
# Vector DB and metadata saved.
